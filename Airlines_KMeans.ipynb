# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashrit77/Assignments/blob/main/Airlines_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
air = pd.read_csv("/content/EastWestAirlines.csv")

# %%
air.head()
# Out:
#    ID#  Balance  Qual_miles  ...  Flight_trans_12  Days_since_enroll  Award?
# 0    1    28143           0  ...                0               7000       0
# 1    2    19244           0  ...                0               6968       0
# 2    3    41354           0  ...                0               7034       0
# 3    4    14776           0  ...                0               6952       0
# 4    5    97752           0  ...                4               6935       1
#
# [5 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
air_df = scalar.fit_transform(air.iloc[:,1:])

# %%
air_df
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
wcss = []
for i in range (1,11):
  kmeans = KMeans(n_clusters=i,random_state=0)
  kmeans.fit(air_df)
  wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title("Elbow plot")
plt.xlabel("No. of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
cluster_new = KMeans(5,random_state=42) 
cluster_new.fit(air_df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
cluster_new.labels_
# Out:
# array([1, 1, 1, ..., 2, 1, 1], dtype=int32)

# %%
air["clusterid_name"] = cluster_new.labels_

# %%
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid_name
# 0          Alabama    13.2      236        58  21.2               0
# 1           Alaska    10.0      263        48  44.5               3
# 2          Arizona     8.1      294        80  31.0               3
# 3         Arkansas     8.8      190        50  19.5               0
# 4       California     9.0      276        91  40.6               3
# 5         Colorado     7.9      204        78  38.7               3
# 6      Connecticut     3.3      110        77  11.1               1
# 7         Delaware     5.9      238        72  15.8               1
# 8          Florida    15.4      335        80  31.9               3
# 9          Georgia    17.4      211        60  25.8               0
# 10          Hawaii     5.3       46        83  20.2               1
# 11           Idaho     2.6      120        54  14.2               2
# 12        Illinois    10.4      249        83  24.0               3
# ...

# %%
air.groupby(["clusterid_name"]).agg(["mean"]).reset_index()
# Out:
#   clusterid_name          ID#  ... Days_since_enroll    Award?
#                          mean  ...              mean      mean
# 0              0  2057.295082  ...       3971.491803  0.557377
# 1              1  2237.521395  ...       3703.870444  0.200872
# 2              2  1598.158147  ...       4890.685304  0.650160
# 3              3  1757.802721  ...       4673.081633  0.802721
# 4              4  1664.866667  ...       4613.866667  0.533333
#
# [5 rows x 13 columns]
