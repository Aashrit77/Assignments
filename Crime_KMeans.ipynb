# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashrit77/Assignments/blob/main/Crime_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
crime = pd.read_csv("/content/crime_data (1).csv")

# %%
crime.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
cri_df = scalar.fit_transform(crime.iloc[:,1:])

# %%
cri_df
# Out:
# array([[ 1.25517927,  0.79078716, -0.52619514, -0.00345116],
#        [ 0.51301858,  1.11805959, -1.22406668,  2.50942392],
#        [ 0.07236067,  1.49381682,  1.00912225,  1.05346626],
#        [ 0.23470832,  0.23321191, -1.08449238, -0.18679398],
#        [ 0.28109336,  1.2756352 ,  1.77678094,  2.08881393],
#        [ 0.02597562,  0.40290872,  0.86954794,  1.88390137],
#        [-1.04088037, -0.73648418,  0.79976079, -1.09272319],
#        [-0.43787481,  0.81502956,  0.45082502, -0.58583422],
#        [ 1.76541475,  1.99078607,  1.00912225,  1.1505301 ],
#        [ 2.22926518,  0.48775713, -0.38662083,  0.49265293],
#        [-0.57702994, -1.51224105,  1.21848371, -0.11129987],
#        [-1.20322802, -0.61527217, -0.80534376, -0.75839217],
#        [ 0.60578867,  0.94836277,  1.21848371,  0.29852525],
#        [-0.13637203, -0.70012057, -0.03768506, -0.0250209 ],
#        [-1.29599811, -1.39102904, -0.5959823 , -1.07115345],
# ...

# %%
wcss = []
for i in range (1,11):
  kmeans = KMeans(n_clusters=i,random_state=0)
  kmeans.fit(cri_df)
  wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title("Elbow plot")
plt.xlabel("No. of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
cluster_new = KMeans(4,random_state=42) 
cluster_new.fit(cri_df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
cluster_new.labels_
# Out:
# array([0, 3, 3, 0, 3, 3, 1, 1, 3, 0, 1, 2, 3, 1, 2, 1, 2, 0, 2, 3, 1, 3,
#        2, 0, 3, 2, 2, 3, 2, 1, 3, 3, 0, 2, 1, 1, 1, 1, 1, 0, 2, 0, 3, 1,
#        2, 1, 1, 2, 2, 1], dtype=int32)

# %%
crime["clusterid_name"] = cluster_new.labels_

# %%
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid_name
# 0          Alabama    13.2      236        58  21.2               0
# 1           Alaska    10.0      263        48  44.5               3
# 2          Arizona     8.1      294        80  31.0               3
# 3         Arkansas     8.8      190        50  19.5               0
# 4       California     9.0      276        91  40.6               3
# 5         Colorado     7.9      204        78  38.7               3
# 6      Connecticut     3.3      110        77  11.1               1
# 7         Delaware     5.9      238        72  15.8               1
# 8          Florida    15.4      335        80  31.9               3
# 9          Georgia    17.4      211        60  25.8               0
# 10          Hawaii     5.3       46        83  20.2               1
# 11           Idaho     2.6      120        54  14.2               2
# 12        Illinois    10.4      249        83  24.0               3
# ...

# %%
crime.groupby(["clusterid_name"]).agg(["mean"]).reset_index()
# Out:
#   clusterid_name     Murder     Assault   UrbanPop       Rape
#                        mean        mean       mean       mean
# 0              0  13.937500  243.625000  53.750000  21.412500
# 1              1   5.656250  138.875000  73.875000  18.781250
# 2              2   3.600000   78.538462  52.076923  12.176923
# 3              3  10.815385  257.384615  76.000000  33.192308
